# %% [markdown]
# ### OSM footprints
#
# making some footprint of place that mean a lot to me personally. Code + fucntion from:
#
# https://github.com/gboeing/osmnx-examples/blob/master/notebooks/10-building-footprints.ipynb

# %%
import osmnx as ox
import pandas as pd
pd.set_option('display.max_columns', 100)
from IPython.display import Image
# %matplotlib inline
ox.config(log_console=True, use_cache=True)

# %%
ox.__version__
# Out:
# '0.8.1'

# %%
# configure the inline image display
img_folder = 'images'
extension = 'png'
size = 500
dist = 1500

# %%
# helper funcion to get one-square-mile street networks, building footprints, and plot them
def make_plot(place, point, network_type='drive', bldg_color='orange', dpi=90,
              dist=805, default_width=4, street_widths=None):
    gdf = ox.buildings_from_point(point=point, distance=dist)
    gdf_proj = ox.project_gdf(gdf)
    fig, ax = ox.plot_figure_ground(point=point, dist=dist, network_type=network_type, 
                                    default_width=default_width, 
                                    street_widths=street_widths, 
                                    save=False, show=False, close=True)
    fig, ax = ox.plot_buildings(gdf_proj, fig=fig, ax=ax, color=bldg_color, figsize=(10,10),
                                set_bounds=False, save=True, show=False, close=True, 
                                filename=place, dpi=dpi)

# %%
place= 'koulouba, Ouagadougou, Burkina Faso'
point = 12.364990, -1.518527
make_plot(place, point)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %%
place= 'legmeerplein, amsterdam'
point = (52.351644, 4.851248)
make_plot(place, point)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %%
place = 'place bellecour, Lyon, France'
point = (45.757820, 4.831928)
make_plot(place, point)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %%
place = 'calle juderia 1, cordoba, spain'
point = (37.879545, -4.780735)
make_plot(place, point)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %%
place = '1700 pennsylvania ave NW, washington DC, USA'
point = (38.898301, -77.039701)
make_plot(place, point)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %%
place = 'piedras 100-52, Buenos Aires'
point = (-34.608827, -58.378181)
make_plot(place, point)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %%
place = 'aankomstpassage 19, schiphol'
point = (52.309547, 4.762820)
make_plot(place, point)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %%
point = (52.351644, 4.851248)
gdf = ox.buildings_from_point(point=point, distance=dist)
gdf_proj = ox.project_gdf(gdf)
bbox = ox.bbox_from_point(point=point, distance=dist, project_utm=True)
fig, ax = ox.plot_buildings(gdf_proj, bgcolor='#333333', color='w', figsize=(10,10), 
                            bbox=bbox, save=True, show=False, close=True, 
                            filename='Hoofddorppleinbuurt', dpi=90)
Image('{}/{}.{}'.format(img_folder, 'Hoofddorppleinbuurt', extension), height=size, width=size)
